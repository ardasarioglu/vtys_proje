# %%
import sqlite3

# %%
connection = sqlite3.connect("database.db")

# %%
cursor = connection.cursor()

# %% [markdown]
# AŞAĞIYA KODU YAZDIKTAN SONRA HER SEFERİNDE SİL!

# %% [markdown]
# sorgular için:
# cursor.execute(
#     """
#         //Bu kısıma sorguyu yaz
#     """
# )
